# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
df =pd.read_csv('bike_sales_india.csv',na_values=["Not Available","n.a."])
print(df)
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year of Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         6750 non-null   object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Avg Daily Distance (km)    Price (INR)  Year of Manufacture  \
# count             10000.000000   10000.000000         10000.000000
# mean                 42.533128  224328.722400          2019.510500
# std                  21.676985  100753.660447             2.907668
# min                   5.010000   50031.000000          2015.000000
# 25%                  23.907500  137900.250000          2017.000000
# 50%                  42.480000  223878.000000          2019.000000
# 75%                  61.352500  311464.250000          2022.000000
# max                  80.000000  399981.000000          2024.000000
#
#        Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# count          10000.000000    10000.000000        10000.00000
# mean             552.695300       67.188926         2020.96510
# std              261.176292       20.891728            2.74897
# min              100.000000       25.000000         2015.00000
# ...

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.isnull().sum()
# Out:
# State                         0
# Avg Daily Distance (km)       0
# Brand                         0
# Model                         0
# Price (INR)                   0
# Year of Manufacture           0
# Engine Capacity (cc)          0
# Fuel Type                     0
# Mileage (km/l)                0
# Owner Type                    0
# Registration Year             0
# Insurance Status           3250
# Seller Type                   0
# Resale Price (INR)            0
# City Tier                     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.isna().any()
# Out:
# State                      False
# Avg Daily Distance (km)    False
# Brand                      False
# Model                      False
# Price (INR)                False
# Year of Manufacture        False
# Engine Capacity (cc)       False
# Fuel Type                  False
# Mileage (km/l)             False
# Owner Type                 False
# Registration Year          False
# Insurance Status            True
# Seller Type                False
# Resale Price (INR)         False
# City Tier                  False
# Price (USD)                False
# Avg Year Distance (km)     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# State                         0
# Avg Daily Distance (km)       0
# Brand                         0
# Model                         0
# Price (INR)                   0
# Year of Manufacture           0
# Engine Capacity (cc)          0
# Fuel Type                     0
# Mileage (km/l)                0
# Owner Type                    0
# Registration Year             0
# Insurance Status           3250
# Seller Type                   0
# Resale Price (INR)            0
# City Tier                     0
# Price (USD)                   0
# Avg Year Distance (km)        0
# dtype: int64

# %%
df.dropna()
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 6        Maharashtra                    77.95  Royal Enfield   Meteor 350
# ...              ...                      ...            ...          ...
# 9993         Gujarat                    45.35         Yamaha        MT-15
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Avg Daily Distance (km)', 'Brand', 'Model', 'Price (INR)',
#        'Year of Manufacture', 'Engine Capacity (cc)', 'Fuel Type',
#        'Mileage (km/l)', 'Owner Type', 'Registration Year', 'Insurance Status',
#        'Seller Type', 'Resale Price (INR)', 'City Tier'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df["Price (USD)"]=df["Price (INR)"]/86.65

# %%
df[df["Price (USD)"]==df["Price (USD)"].max()]
# Out:
#                State  Avg Daily Distance (km)          Brand       Model  \
# 7490  Madhya Pradesh                    64.45  Royal Enfield  Meteor 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# 7490       399981                 2019                   453  Electric
#
#       Mileage (km/l) Owner Type  Registration Year Insurance Status  \
# 7490           95.49      First               2019              NaN
#
#      Seller Type  Resale Price (INR) City Tier  Price (USD)
# 7490  Individual           305334.45    Tier 1  4616.053087

# %%
df.groupby(by="State").mean(numeric_only=True).sort_values("Price (USD)",ascending=False)
# Out:
#                 Avg Daily Distance (km)    Price (INR)  Year of Manufacture  \
# State
# Delhi                         41.336192  228109.786080          2019.360287
# Uttar Pradesh                 42.921097  227511.102692          2019.295115
# Tamil Nadu                    42.998189  226715.380282          2019.474849
# Punjab                        42.831931  226566.136061          2019.511893
# Gujarat                       41.627814  226440.647705          2019.451098
# Karnataka                     42.746925  225220.251527          2019.637475
# West Bengal                   42.698723  221925.126674          2019.530381
# Rajasthan                     43.149882  220819.930187          2019.621436
# Maharashtra                   42.134282  220031.651456          2019.595146
# Madhya Pradesh                42.866033  219936.943474          2019.625899
#
#                 Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# State
# ...

# %%
df["Avg Year Distance (km)"]=df["Avg Daily Distance (km)"]*365
ye=df.groupby(by="Registration Year").mean(numeric_only=True)[["Avg Year Distance (km)"]]
plt.figure(figsize=(16,6))
plt.plot(ye.index , ye["Avg Year Distance (km)"])
plt.show()

# %%
ye=df.groupby(by="Registration Year").mean(numeric_only=True)[["Price (USD)"]]
plt.plot(ye.index , ye["Price (USD)"])
plt.show()

# %%
# 1. Distribution of Bike Prices
plt.figure(figsize=(10, 5))
sns.histplot(df["Price (INR)"], bins=50, kde=True, color='blue')
plt.title("Distribution of Bike Prices")
plt.xlabel("Price (INR)")
plt.ylabel("Frequency")
plt.show()

# %%
# 2. Average Price by Brand
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x="Brand", y="Price (INR)", estimator=np.mean, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Average Bike Price by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Price (INR)")
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_9736\3980624718.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Brand", y="Price (INR)", estimator=np.mean, palette="coolwarm")

# %%
# 3. Boxplot: Price Distribution by Brand
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Brand", y="Price (INR)", palette="pastel")
plt.xticks(rotation=45)
plt.title("Price Distribution Across Brands")
plt.xlabel("Brand")
plt.ylabel("Price (INR)")
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_9736\1271870962.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Brand", y="Price (INR)", palette="pastel")

# %%
# 4. Correlation Heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 5. Fuel Type Distribution
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Fuel Type", palette="Set2")
plt.title("Distribution of Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_9736\2079242588.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Fuel Type", palette="Set2")

# %%
# 6. City Tier vs. Bike Price
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="City Tier", y="Price (INR)", palette="husl")
plt.title("Bike Prices by City Tier")
plt.xlabel("City Tier")
plt.ylabel("Price (INR)")
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_9736\4285340517.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="City Tier", y="Price (INR)", palette="husl")

# %%
# 7. Engine Capacity vs. Price Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Engine Capacity (cc)", y="Price (INR)", hue="Brand", alpha=0.7)
plt.title("Engine Capacity vs. Bike Price")
plt.xlabel("Engine Capacity (cc)")
plt.ylabel("Price (INR)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df.columns
# Out:
# Index(['State', 'Avg Daily Distance (km)', 'Brand', 'Model', 'Price (INR)',
#        'Year of Manufacture', 'Engine Capacity (cc)', 'Fuel Type',
#        'Mileage (km/l)', 'Owner Type', 'Registration Year', 'Insurance Status',
#        'Seller Type', 'Resale Price (INR)', 'City Tier'],
#       dtype='object')

# %%
df.groupby('Model')['Brand'].value_counts().plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>
